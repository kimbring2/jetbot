# %%
from IPython.display import display, HTML, clear_output
from IPython.display import Image as IPython_Image
import PIL.Image
import os
import cv2
import numpy as np

print("os.getcwd(): ", os.getcwd())

def arrayShow(imageArray):
    image = bytes(cv2.imencode('.jpg', imageArray)[1])
    return IPython_Image(data=image)

# Read image and run image encoder
pil_image = PIL.Image.open("/home/kimbring2/nanosam/assets/dogs.jpg")
open_cv_image = np.array(pil_image)
open_cv_image = open_cv_image[:, :, ::-1].copy()

arrayShow(open_cv_image)
# Out:
# os.getcwd():  /home/kimbring2/jetbot/notebooks/generative_ai

# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image
from nanosam.utils.predictor import Predictor

image_encoder = "/home/kimbring2/nanosam/data/resnet18_image_encoder.engine"
mask_decoder = "/home/kimbring2/nanosam/data/mobile_sam_mask_decoder.engine"

# Instantiate TensorRT predictor
predictor = Predictor(image_encoder, mask_decoder)
# Out:
# [01/24/2024-12:47:15] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [01/24/2024-12:47:15] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.

# %%
import cv2
import numpy as np
from PIL import Image

#image = PIL.Image.open("/home/kimbring2/nanosam/assets/dogs.jpg")
img = cv2.imread("/home/kimbring2/nanosam/assets/dogs.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print("img.shape: ", img.shape)

im_pil = Image.fromarray(img)
predictor.set_image(im_pil)

# Segment using bounding box
bbox = [100, 100, 850, 759]  # x0, y0, x1, y1

points = np.array([[bbox[0], bbox[1]], [bbox[2], bbox[3]]])

point_labels = np.array([2, 3])

mask, _, _ = predictor.predict(points, point_labels)
mask = (mask[0, 0] > 0).detach().cpu().numpy()
mask = np.asarray(mask, dtype="uint8")

color = np.array([0,128,0], dtype='uint8')
masked_img = np.where(mask[...,None], color, img)

out = cv2.addWeighted(img, 0.2, masked_img, 0.8, 0)
#cv2.imwrite("masked_img.png", masked_img)
# Draw resykts
plt.imshow(out)

#plt.imshow(img)
#plt.imshow(mask, alpha=0.5)
#x = [bbox[0], bbox[2], bbox[2], bbox[0], bbox[0]]
#y = [bbox[1], bbox[1], bbox[3], bbox[3], bbox[1]]
#plt.plot(x, y, 'g-')
#plt.savefig("/home/kimbring2/Desktop/basic_usage_out.jpg")
# Out:
# img.shape:  (760, 1180, 3)
# /home/kimbring2/nanosam/nanosam/utils/predictor.py:84: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /opt/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:206.)
#   image_torch_resized = torch.from_numpy(image_np_resized).permute(2, 0, 1)
# /home/kimbring2/nanosam/nanosam/utils/predictor.py:103: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:245.)
#   image_point_coords = torch.tensor([points]).float().cuda()

# %%
import cv2
from matplotlib import pyplot as plt


def gstreamer_pipeline(sensor_id=1, capture_width=1920, capture_height=1080, display_width=960, display_height=540, framerate=30, 
                       flip_method=0,):
    return (
        "nvarguscamerasrc sensor-id=%d ! "
        "video/x-raw(memory:NVMM), width=(int)%d, height=(int)%d, framerate=(fraction)%d/1 ! "
        "nvvidconv flip-method=%d ! "
        "video/x-raw, width=(int)%d, height=(int)%d, format=(string)BGRx ! "
        "videoconvert ! "
        "video/x-raw, format=(string)BGR ! appsink"
        % (sensor_id, capture_width, capture_height, framerate, flip_method, display_width, display_height))


def show_camera():
    path_raw_video = '/home/kimbring2/Desktop/raw_video.avi'
    
    fps = 15
    raw_video_out = cv2.VideoWriter(path_raw_video, cv2.VideoWriter_fourcc(*'DIVX'), fps, (1180,760))

    # To flip the image, modify the flip_method parameter (0 and 2 are the most common)
    video_capture = cv2.VideoCapture(gstreamer_pipeline(flip_method=0), cv2.CAP_GSTREAMER)
    frame_num = 0
    
    #print("video_capture.isOpened(): ",  video_capture.isOpened())
    if video_capture.isOpened():
        try:
            while True:
                ret_val, frame = video_capture.read()
                #print("frame.shape: ", frame.shape)
                
                #if frame != None:
                print("frame_num: ", frame_num)
                
                frame = cv2.resize(frame, (1180, 760), interpolation=cv2.INTER_AREA)
                print("frame.shape: ", frame.shape)
                #raw_video_out.write(frame)
                
                im_pil = Image.fromarray(frame)
                predictor.set_image(im_pil)
                
                bbox = [100, 100, 850, 759]  # x0, y0, x1, y1
                
                points = np.array([[bbox[0], bbox[1]], [bbox[2], bbox[3]]])
                
                point_labels = np.array([2, 3])
                
                mask, _, _ = predictor.predict(points, point_labels)
                mask = (mask[0, 0] > 0).detach().cpu().numpy()
                mask = np.asarray(mask, dtype="uint8")
                
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask)
                #print("dilation_image.shape: ", dilation_image.shape)

                raw_video_out.write(masked_frame)
                #mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
                #mask = cv2.resize(mask, (640, 360), interpolation=cv2.INTER_AREA)
                #print("mask.shape: ", mask.shape)

                #cv2.imwrite("mask.png", mask)
                
                #mask_video_out.write(mask)
    
                #plt.imshow(frame)
                #plt.imshow(mask, alpha=0.5)
                #x = [bbox[0], bbox[2], bbox[2], bbox[0], bbox[0]]
                #y = [bbox[1], bbox[1], bbox[3], bbox[3], bbox[1]]
                #plt.plot(x, y, 'g-')   
    
                frame_num += 1

                #break
        finally:
            video_capture.release()
    else:
        print("Error: Unable to open camera")

show_camera()
# Out:
# GST_ARGUS: Creating output stream
# CONSUMER: Waiting until producer is connected...
# GST_ARGUS: Available Sensor modes :
# GST_ARGUS: 3280 x 2464 FR = 21.000000 fps Duration = 47619048 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 3280 x 1848 FR = 28.000001 fps Duration = 35714284 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1920 x 1080 FR = 29.999999 fps Duration = 33333334 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1640 x 1232 FR = 29.999999 fps Duration = 33333334 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: 1280 x 720 FR = 59.999999 fps Duration = 16666667 ; Analog Gain range min 1.000000, max 10.625000; Exposure Range min 13000, max 683709000;
#
# GST_ARGUS: Running with following settings:
#    Camera index = 0
#    Camera mode  = 2
#    Output Stream W = 1920 H = 1080
#    seconds to Run    = 0
#    Frame Rate = 29.999999
# GST_ARGUS: Setup Complete, Starting captures for 0 seconds
# GST_ARGUS: Starting repeat capture requests.
# CONSUMER: Producer has connected; continuing.
# frame_num:  0
# frame.shape:  (760, 1180, 3)
# [ WARN:0] global /home/ubuntu/build_opencv/opencv/modules/videoio/src/cap_gstreamer.cpp (1100) open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# frame_num:  1
# frame.shape:  (760, 1180, 3)
# frame_num:  2
# frame.shape:  (760, 1180, 3)
# frame_num:  3
# frame.shape:  (760, 1180, 3)
# frame_num:  4
# frame.shape:  (760, 1180, 3)
# frame_num:  5
# frame.shape:  (760, 1180, 3)
# frame_num:  6
# frame.shape:  (760, 1180, 3)
# frame_num:  7
# frame.shape:  (760, 1180, 3)
# frame_num:  8
# frame.shape:  (760, 1180, 3)
# frame_num:  9
# frame.shape:  (760, 1180, 3)
# frame_num:  10
# frame.shape:  (760, 1180, 3)
# frame_num:  11
# frame.shape:  (760, 1180, 3)
# frame_num:  12
# frame.shape:  (760, 1180, 3)
# frame_num:  13
# frame.shape:  (760, 1180, 3)
# frame_num:  14
# frame.shape:  (760, 1180, 3)
# frame_num:  15
# frame.shape:  (760, 1180, 3)
# frame_num:  16
# frame.shape:  (760, 1180, 3)
# frame_num:  17
# frame.shape:  (760, 1180, 3)
# frame_num:  18
# frame.shape:  (760, 1180, 3)
# frame_num:  19
# frame.shape:  (760, 1180, 3)
# frame_num:  20
# frame.shape:  (760, 1180, 3)
# frame_num:  21
# frame.shape:  (760, 1180, 3)
# frame_num:  22
# frame.shape:  (760, 1180, 3)
# frame_num:  23
# frame.shape:  (760, 1180, 3)
# frame_num:  24
# frame.shape:  (760, 1180, 3)
# frame_num:  25
# frame.shape:  (760, 1180, 3)
# frame_num:  26
# frame.shape:  (760, 1180, 3)
# frame_num:  27
# frame.shape:  (760, 1180, 3)
# frame_num:  28
# frame.shape:  (760, 1180, 3)
# frame_num:  29
# frame.shape:  (760, 1180, 3)
# frame_num:  30
# frame.shape:  (760, 1180, 3)
# frame_num:  31
# frame.shape:  (760, 1180, 3)
# frame_num:  32
# frame.shape:  (760, 1180, 3)
# frame_num:  33
# frame.shape:  (760, 1180, 3)
# frame_num:  34
# frame.shape:  (760, 1180, 3)
# frame_num:  35
# frame.shape:  (760, 1180, 3)
# frame_num:  36
# frame.shape:  (760, 1180, 3)
# frame_num:  37
# frame.shape:  (760, 1180, 3)
# frame_num:  38
# frame.shape:  (760, 1180, 3)
# frame_num:  39
# frame.shape:  (760, 1180, 3)
# frame_num:  40
# frame.shape:  (760, 1180, 3)
# frame_num:  41
# frame.shape:  (760, 1180, 3)
# frame_num:  42
# frame.shape:  (760, 1180, 3)
# frame_num:  43
# frame.shape:  (760, 1180, 3)
# frame_num:  44
# frame.shape:  (760, 1180, 3)
# frame_num:  45
# frame.shape:  (760, 1180, 3)
# frame_num:  46
# frame.shape:  (760, 1180, 3)
# frame_num:  47
# frame.shape:  (760, 1180, 3)
# frame_num:  48
# frame.shape:  (760, 1180, 3)
# frame_num:  49
# frame.shape:  (760, 1180, 3)
# frame_num:  50
# frame.shape:  (760, 1180, 3)
# frame_num:  51
# frame.shape:  (760, 1180, 3)
# frame_num:  52
# frame.shape:  (760, 1180, 3)
# frame_num:  53
# frame.shape:  (760, 1180, 3)
# frame_num:  54
# frame.shape:  (760, 1180, 3)
# frame_num:  55
# frame.shape:  (760, 1180, 3)
# frame_num:  56
# frame.shape:  (760, 1180, 3)
# frame_num:  57
# frame.shape:  (760, 1180, 3)
# frame_num:  58
# frame.shape:  (760, 1180, 3)
# frame_num:  59
# frame.shape:  (760, 1180, 3)
# frame_num:  60
# frame.shape:  (760, 1180, 3)
# frame_num:  61
# frame.shape:  (760, 1180, 3)
# frame_num:  62
# frame.shape:  (760, 1180, 3)
# frame_num:  63
# frame.shape:  (760, 1180, 3)
# frame_num:  64
# frame.shape:  (760, 1180, 3)
# frame_num:  65
# frame.shape:  (760, 1180, 3)
# frame_num:  66
# frame.shape:  (760, 1180, 3)
# frame_num:  67
# frame.shape:  (760, 1180, 3)
# frame_num:  68
# frame.shape:  (760, 1180, 3)
# frame_num:  69
# frame.shape:  (760, 1180, 3)
# frame_num:  70
# frame.shape:  (760, 1180, 3)
# frame_num:  71
# frame.shape:  (760, 1180, 3)
# frame_num:  72
# frame.shape:  (760, 1180, 3)
# frame_num:  73
# frame.shape:  (760, 1180, 3)
# frame_num:  74
# frame.shape:  (760, 1180, 3)
# frame_num:  75
# frame.shape:  (760, 1180, 3)
# frame_num:  76
# frame.shape:  (760, 1180, 3)
# frame_num:  77
# frame.shape:  (760, 1180, 3)
# frame_num:  78
# frame.shape:  (760, 1180, 3)
# frame_num:  79
# frame.shape:  (760, 1180, 3)
# frame_num:  80
# frame.shape:  (760, 1180, 3)
# frame_num:  81
# frame.shape:  (760, 1180, 3)
# frame_num:  82
# frame.shape:  (760, 1180, 3)
# frame_num:  83
# frame.shape:  (760, 1180, 3)
# frame_num:  84
# frame.shape:  (760, 1180, 3)
# frame_num:  85
# frame.shape:  (760, 1180, 3)
# frame_num:  86
# frame.shape:  (760, 1180, 3)
# frame_num:  87
# frame.shape:  (760, 1180, 3)
# frame_num:  88
# frame.shape:  (760, 1180, 3)
# frame_num:  89
# frame.shape:  (760, 1180, 3)
# frame_num:  90
# frame.shape:  (760, 1180, 3)
# frame_num:  91
# frame.shape:  (760, 1180, 3)
# frame_num:  92
# frame.shape:  (760, 1180, 3)
# frame_num:  93
# frame.shape:  (760, 1180, 3)
# frame_num:  94
# frame.shape:  (760, 1180, 3)
# frame_num:  95
# frame.shape:  (760, 1180, 3)
# frame_num:  96
# frame.shape:  (760, 1180, 3)
# frame_num:  97
# frame.shape:  (760, 1180, 3)
# frame_num:  98
# frame.shape:  (760, 1180, 3)
# frame_num:  99
# frame.shape:  (760, 1180, 3)
# frame_num:  100
# frame.shape:  (760, 1180, 3)
# frame_num:  101
# frame.shape:  (760, 1180, 3)
# frame_num:  102
# frame.shape:  (760, 1180, 3)
# frame_num:  103
# frame.shape:  (760, 1180, 3)
# frame_num:  104
# frame.shape:  (760, 1180, 3)
# frame_num:  105
# frame.shape:  (760, 1180, 3)
# frame_num:  106
# frame.shape:  (760, 1180, 3)
# frame_num:  107
# frame.shape:  (760, 1180, 3)
# frame_num:  108
# frame.shape:  (760, 1180, 3)
# frame_num:  109
# frame.shape:  (760, 1180, 3)
# frame_num:  110
# frame.shape:  (760, 1180, 3)
# frame_num:  111
# frame.shape:  (760, 1180, 3)
# frame_num:  112
# frame.shape:  (760, 1180, 3)
# frame_num:  113
# frame.shape:  (760, 1180, 3)
# frame_num:  114
# frame.shape:  (760, 1180, 3)
# frame_num:  115
# frame.shape:  (760, 1180, 3)
# frame_num:  116
# frame.shape:  (760, 1180, 3)
# frame_num:  117
# frame.shape:  (760, 1180, 3)
# frame_num:  118
# frame.shape:  (760, 1180, 3)
# frame_num:  119
# frame.shape:  (760, 1180, 3)
# frame_num:  120
# frame.shape:  (760, 1180, 3)
# frame_num:  121
# frame.shape:  (760, 1180, 3)
# frame_num:  122
# frame.shape:  (760, 1180, 3)
# frame_num:  123
# frame.shape:  (760, 1180, 3)
# frame_num:  124
# frame.shape:  (760, 1180, 3)
# frame_num:  125
# frame.shape:  (760, 1180, 3)
# frame_num:  126
# frame.shape:  (760, 1180, 3)
# frame_num:  127
# frame.shape:  (760, 1180, 3)
# frame_num:  128
# frame.shape:  (760, 1180, 3)
# frame_num:  129
# frame.shape:  (760, 1180, 3)
# frame_num:  130
# frame.shape:  (760, 1180, 3)
# frame_num:  131
# frame.shape:  (760, 1180, 3)
# frame_num:  132
# frame.shape:  (760, 1180, 3)
# frame_num:  133
# frame.shape:  (760, 1180, 3)
# frame_num:  134
# frame.shape:  (760, 1180, 3)
# frame_num:  135
# frame.shape:  (760, 1180, 3)
# frame_num:  136
# frame.shape:  (760, 1180, 3)
# frame_num:  137
# frame.shape:  (760, 1180, 3)
# frame_num:  138
# frame.shape:  (760, 1180, 3)
# frame_num:  139
# frame.shape:  (760, 1180, 3)
# frame_num:  140
# frame.shape:  (760, 1180, 3)
# frame_num:  141
# frame.shape:  (760, 1180, 3)
# frame_num:  142
# frame.shape:  (760, 1180, 3)
# frame_num:  143
# frame.shape:  (760, 1180, 3)
# frame_num:  144
# frame.shape:  (760, 1180, 3)
# frame_num:  145
# frame.shape:  (760, 1180, 3)
# frame_num:  146
# frame.shape:  (760, 1180, 3)
# frame_num:  147
# frame.shape:  (760, 1180, 3)
# frame_num:  148
# frame.shape:  (760, 1180, 3)
# frame_num:  149
# frame.shape:  (760, 1180, 3)
# frame_num:  150
# frame.shape:  (760, 1180, 3)
# frame_num:  151
# frame.shape:  (760, 1180, 3)
# frame_num:  152
# frame.shape:  (760, 1180, 3)
# frame_num:  153
# frame.shape:  (760, 1180, 3)
# frame_num:  154
# frame.shape:  (760, 1180, 3)
# frame_num:  155
# frame.shape:  (760, 1180, 3)
# frame_num:  156
# frame.shape:  (760, 1180, 3)
# frame_num:  157
# frame.shape:  (760, 1180, 3)
# frame_num:  158
# frame.shape:  (760, 1180, 3)
# frame_num:  159
# frame.shape:  (760, 1180, 3)
# frame_num:  160
# frame.shape:  (760, 1180, 3)
# frame_num:  161
# frame.shape:  (760, 1180, 3)
# frame_num:  162
# frame.shape:  (760, 1180, 3)
# frame_num:  163
# frame.shape:  (760, 1180, 3)
# frame_num:  164
# frame.shape:  (760, 1180, 3)
# frame_num:  165
# frame.shape:  (760, 1180, 3)
# frame_num:  166
# frame.shape:  (760, 1180, 3)
# frame_num:  167
# frame.shape:  (760, 1180, 3)
# frame_num:  168
# frame.shape:  (760, 1180, 3)
# frame_num:  169
# frame.shape:  (760, 1180, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 80
#      77     else:
#      78         print("Error: Unable to open camera")
# ---> 80 show_camera()
#
# Cell In[4], line 41, in show_camera()
#      38 print("frame.shape: ", frame.shape)
#      39 #raw_video_out.write(frame)
# ---> 41 im_pil = Image.fromarray(frame)
#      42 predictor.set_image(im_pil)
#      44 bbox = [100, 100, 850, 759]  # x0, y0, x1, y1
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2701, in fromarray(obj, mode)
#    2698     else:
#    2699         obj = obj.tostring()
# -> 2701 return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2641, in frombuffer(mode, size, data, decoder_name, *args)
#    2638         im.readonly = 1
#    2639         return im
# -> 2641 return frombytes(mode, size, data, decoder_name, args)
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2580, in frombytes(mode, size, data, decoder_name, *args)
#    2577 if decoder_name == "raw" and args == ():
#    2578     args = mode
# -> 2580 im = new(mode, size)
#    2581 im.frombytes(data, decoder_name, args)
#    2582 return im
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2544, in new(mode, size, color)
#    2542     im.palette = ImagePalette.ImagePalette()
#    2543     color = im.palette.getcolor(color)
# -> 2544 return im._new(core.fill(mode, size, color))
#
# KeyboardInterrupt:
